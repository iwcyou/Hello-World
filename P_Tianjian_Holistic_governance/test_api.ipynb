# %%
#Load environment variables
import os
# import sys
# sys.path.append('../..')
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %%
from openai import OpenAI

client = OpenAI(api_key=os.environ['W8A8_API_KEY'], base_url="http://223.2.249.70:7019/v1")

response = client.chat.completions.create(
    model="r1w8a8",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": """明天天气怎么样？"""},
    ],
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# <think>
#
# </think>
#
# 您好，建议您联网获取时效性较强的信息；如果还有其他问题需要帮助，请随时告诉我！

# %%
#InternVL3-8B example
from openai import OpenAI

client = OpenAI(api_key=os.environ['INTERNVL_API_KEY'], base_url="http://223.2.249.70:7025/v1")

response = client.chat.completions.create(
    model="InternVL3-8B",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello"},
    ],
    stream=False
)

print(response.choices[0].message.content)
