# %%
import pandas as pd
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Hosp

# %%
diagnoses = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/diagnoses_icd.csv")
diagnoses
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 0          10000032  22595853        1     5723            9
# 1          10000032  22595853        2    78959            9
# 2          10000032  22595853        3     5715            9
# 3          10000032  22595853        4    07070            9
# 4          10000032  22595853        5      496            9
# ...             ...       ...      ...      ...          ...
# 6364483    19999987  23865745        7    41401            9
# 6364484    19999987  23865745        8    78039            9
# 6364485    19999987  23865745        9     0413            9
# 6364486    19999987  23865745       10    36846            9
# 6364487    19999987  23865745       11     7810            9
#
# [6364488 rows x 5 columns]

# %%
dict_diag = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/d_icd_diagnoses.csv")
dict_diag
# Out:
#        icd_code  icd_version  \
# 0          0010            9
# 1          0011            9
# 2          0019            9
# 3          0020            9
# 4          0021            9
# ...         ...          ...
# 112102     Z992           10
# 112103     Z993           10
# 112104     Z998           10
# 112105    Z9981           10
# 112106    Z9989           10
#
#                                                long_title
# 0                          Cholera due to vibrio cholerae
# 1                   Cholera due to vibrio cholerae el tor
# 2                                    Cholera, unspecified
# 3                                           Typhoid fever
# 4                                     Paratyphoid fever A
# ...                                                   ...
# 112102                       Dependence on renal dialysis
# 112103                           Dependence on wheelchair
# 112104  Dependence on other enabling machines and devices
# ...

# %%
admits = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/admissions.csv")
admits
# Out:
#         subject_id   hadm_id            admittime            dischtime  \
# 0         10000032  22595853  2180-05-06 22:23:00  2180-05-07 17:15:00
# 1         10000032  22841357  2180-06-26 18:27:00  2180-06-27 18:49:00
# 2         10000032  25742920  2180-08-05 23:44:00  2180-08-07 17:50:00
# 3         10000032  29079034  2180-07-23 12:35:00  2180-07-25 17:55:00
# 4         10000068  25022803  2160-03-03 23:16:00  2160-03-04 06:26:00
# ...            ...       ...                  ...                  ...
# 546023    19999828  25744818  2149-01-08 16:44:00  2149-01-18 17:00:00
# 546024    19999828  29734428  2147-07-18 16:23:00  2147-08-04 18:10:00
# 546025    19999840  21033226  2164-09-10 13:47:00  2164-09-17 13:42:00
# 546026    19999840  26071774  2164-07-25 00:27:00  2164-07-28 12:15:00
# 546027    19999987  23865745  2145-11-02 21:38:00  2145-11-11 12:57:00
#
#                   deathtime  admission_type admit_provider_id  \
# ...

# %%
patients = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/patients.csv")
patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0         10000032      F          52         2180       2014 - 2016
# 1         10000048      F          23         2126       2008 - 2010
# 2         10000058      F          33         2168       2020 - 2022
# 3         10000068      F          19         2160       2008 - 2010
# 4         10000084      M          72         2160       2017 - 2019
# ...            ...    ...         ...          ...               ...
# 364622    19999828      F          46         2147       2017 - 2019
# 364623    19999829      F          28         2186       2008 - 2010
# 364624    19999840      M          58         2164       2008 - 2010
# 364625    19999914      F          49         2158       2017 - 2019
# 364626    19999987      F          57         2145       2011 - 2013
#
#                dod
# 0       2180-09-09
# 1              NaN
# 2              NaN
# 3              NaN
# 4       2161-02-13
# ...

# %%
poe = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/poe.csv")
poe
# Out:
#                 poe_id  poe_seq  subject_id   hadm_id            ordertime  \
# 0         10000032-100      100    10000032  22841357  2180-06-26 22:09:02
# 1         10000032-101      101    10000032  22841357  2180-06-26 22:09:02
# 2         10000032-102      102    10000032  22841357  2180-06-26 22:09:02
# 3         10000032-103      103    10000032  22841357  2180-06-26 22:09:02
# 4         10000032-104      104    10000032  22841357  2180-06-26 22:09:02
# ...                ...      ...         ...       ...                  ...
# 52212104   19999987-83       83    19999987  23865745  2145-11-04 08:39:45
# 52212105   19999987-84       84    19999987  23865745  2145-11-04 09:00:39
# 52212106   19999987-85       85    19999987  23865745  2145-11-04 09:00:39
# 52212107   19999987-86       86    19999987  23865745  2145-11-04 09:00:39
# 52212108   19999987-87       87    19999987  23865745  2145-11-04 09:45:20
#
#             order_type      order_subtype transaction_type  \
# ...

# %%
labevents = pd.read_csv("/data/kunfeng/mimic-iv-3.1/hosp/labevents.csv")
labevents
# Out:
#            labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 0                    1    10000032         NaN      2704548   50931
# 1                    2    10000032         NaN     36092842   51071
# 2                    3    10000032         NaN     36092842   51074
# 3                    4    10000032         NaN     36092842   51075
# 4                    5    10000032         NaN     36092842   51079
# ...                ...         ...         ...          ...     ...
# 158374759    159057534    19999987  23865745.0     59879875   51279
# 158374760    159057535    19999987  23865745.0     59879875   51301
# 158374761    159057536    19999987         NaN     74914384   50912
# 158374762    159057537    19999987         NaN     74914384   50920
# 158374763    159057538    19999987         NaN     74914384   51006
#
#           order_provider_id            charttime            storetime value  \
# ...

# %% [markdown]
# # Note

# %%
discharge = pd.read_csv("/data/kunfeng/physionet.org/files/mimic-iv-note/2.2/note/discharge.csv")
discharge
# Out:
#                note_id  subject_id   hadm_id note_type  note_seq  \
# 0       10000032-DS-21    10000032  22595853        DS        21
# 1       10000032-DS-22    10000032  22841357        DS        22
# 2       10000032-DS-23    10000032  29079034        DS        23
# 3       10000032-DS-24    10000032  25742920        DS        24
# 4       10000084-DS-17    10000084  23052089        DS        17
# ...                ...         ...       ...       ...       ...
# 331788   19999828-DS-6    19999828  29734428        DS         6
# 331789   19999828-DS-7    19999828  25744818        DS         7
# 331790  19999840-DS-20    19999840  26071774        DS        20
# 331791  19999840-DS-21    19999840  21033226        DS        21
# 331792   19999987-DS-2    19999987  23865745        DS         2
#
#                   charttime            storetime  \
# 0       2180-05-07 00:00:00  2180-05-09 15:26:00
# 1       2180-06-27 00:00:00  2180-07-01 10:15:00
# ...

# %%
discharge_detail = pd.read_csv("/data/kunfeng/physionet.org/files/mimic-iv-note/2.2/note/discharge_detail.csv")
discharge_detail
# Out:
#                note_id  subject_id field_name field_value  field_ordinal
# 0       10000032-DS-21    10000032     author         ___              1
# 1       10000032-DS-22    10000032     author         ___              1
# 2       10000032-DS-23    10000032     author         ___              1
# 3       10000032-DS-24    10000032     author         ___              1
# 4       10000084-DS-17    10000084     author         ___              1
# ...                ...         ...        ...         ...            ...
# 186133  15614172-DS-13    15614172     author         ___              1
# 186134  15614172-DS-14    15614172     author         ___              1
# 186135  15614172-DS-15    15614172     author         ___              1
# 186136  15614172-DS-16    15614172     author         ___              1
# 186137  15614172-DS-17    15614172     author         ___              1
#
# [186138 rows x 5 columns]

# %%
radiology = pd.read_csv("/data/kunfeng/physionet.org/files/mimic-iv-note/2.2/note/radiology.csv")
radiology
# Out:
#                 note_id  subject_id     hadm_id note_type  note_seq  \
# 0        10000032-RR-14    10000032  22595853.0        RR        14
# 1        10000032-RR-15    10000032  22595853.0        RR        15
# 2        10000032-RR-16    10000032  22595853.0        RR        16
# 3        10000032-RR-18    10000032         NaN        RR        18
# 4        10000032-RR-20    10000032         NaN        RR        20
# ...                 ...         ...         ...       ...       ...
# 2321350  19999987-RR-17    19999987  23865745.0        RR        17
# 2321351  19999987-RR-18    19999987  23865745.0        RR        18
# 2321352  19999987-RR-19    19999987  23865745.0        RR        19
# 2321353  19999987-RR-20    19999987  23865745.0        RR        20
# 2321354  19999987-RR-21    19999987  23865745.0        RR        21
#
#                    charttime            storetime  \
# 0        2180-05-06 21:19:00  2180-05-06 23:32:00
# ...

# %%
radiology_detail = pd.read_csv("/data/kunfeng/physionet.org/files/mimic-iv-note/2.2/note/radiology_detail.csv")
radiology_detail
# Out:
#                 note_id  subject_id field_name                field_value  \
# 0        10000032-RR-14    10000032  exam_code                        C11
# 1        10000032-RR-14    10000032  exam_name           CHEST (PA & LAT)
# 2        10000032-RR-15    10000032  exam_code                       U314
# 3        10000032-RR-15    10000032  exam_code                       U644
# 4        10000032-RR-15    10000032  exam_code                        W82
# ...                 ...         ...        ...                        ...
# 6046116  19999987-RR-21    19999987  exam_name     PLACE CATH CAROTID ART
# 6046117  19999987-RR-21    19999987  exam_name     PLACE CATH CAROTID ART
# 6046118  19999987-RR-21    19999987  exam_name   PLACE CATH VERTEBRAL ART
# 6046119  19999987-RR-21    19999987  exam_name  PLACE CATH XTRNL CAROTID
# 6046120  19999987-RR-21    19999987  exam_name  PLACE CATH XTRNL CAROTID
#
#          field_ordinal
# 0                    1
# 1                    1
# ...
