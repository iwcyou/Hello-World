# %%
#DeepSeek-R1 Model Example
from openai import OpenAI

client = OpenAI(api_key="sk-cg-r1w8a8-5e9f673e115a77224b8ed56a8c699f6bbec22a4", base_url="http://223.2.249.70:7019/v1")

response = client.chat.completions.create(
    model="r1w8a8",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": """你好，你能把我发你的文字转换为富文本输出吗？要求是html格式，请对其中关键信息显示为蓝色或红色。
{
  "eventId": "SX-2025-06-19-00001",
  "sceneType": "泥头车",
  "reportLocation": "广东省深圳市福田区梅林街道林海山庄",
  "gridCode": "440304008004003",
  "reportTime": "2025-06-20 06:48:20",
  "reporter": "张三",
  "reporter subject": "城市管家",
  "imageUrls": [
    "https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/811702d688c348f8b0be009cb9b2805d.jpg",
    "https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/7c7e65a9840b45688289c2b0be4da81a.jpg"
  ],
  "longitude": 121.473,
  "latitude": 31.230,
  "description": "滨河路。东往西滨河新洲立交处，该车辆超高超载。未密闭，沿途撒落。"
}"""},
    ],
    stream=True
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 31
#       4 client = OpenAI(api_key="sk-cg-r1w8a8-5e9f673e115a77224b8ed56a8c699f6bbec22a4", base_url="http://223.2.249.70:7019/v1")
#       6 response = client.chat.completions.create(
#       7     model="r1w8a8",
#       8     messages=[
#    (...)     28     stream=True
#      29 )
# ---> 31 print(response.choices[0].message.content)
#
# AttributeError: 'Stream' object has no attribute 'choices'

# %%
from openai import OpenAI

client = OpenAI(api_key="sk-cg-r1w8a8-5e9f673e115a77224b8ed56a8c699f6bbec22a4", base_url="http://223.2.249.70:7019/v1")

response = client.chat.completions.create(
    model="r1w8a8",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": """你好，你能把我发你的文字转换为富文本输出吗？要求是html格式，请对其中关键信息显示为蓝色或红色。
{
  "eventId": "SX-2025-06-19-00001",
  "sceneType": "泥头车",
  "reportLocation": "广东省深圳市福田区梅林街道林海山庄",
  "gridCode": "440304008004003",
  "reportTime": "2025-06-20 06:48:20",
  "reporter": "张三",
  "reporter subject": "城市管家",
  "imageUrls": [
    "https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/811702d688c348f8b0be009cb9b2805d.jpg",
    "https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/7c7e65a9840b45688289c2b0be4da81a.jpg"
  ],
  "longitude": 121.473,
  "latitude": 31.230,
  "description": "滨河路。东往西滨河新洲立交处，该车辆超高超载。未密闭，沿途撒落。"
}"""},
    ],
    stream=True
)

for chunk in response:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="", flush=True)
# Out:
# <think>
# 好的，我现在需要处理用户发来的请求，将提供的JSON数据转换为HTML格式的富文本，同时将关键信息用蓝色或红色显示。首先，我得仔细分析用户的需求，确保理解正确。
#
# 用户的要求很明确：生成HTML，关键信息用蓝色或红色。关键信息可能包括事件ID、地点、时间、上报人等。我需要确定哪些字段是关键信息。通常，事件ID、地点、时间、上报人这些比较重要，应该高亮显示。接下来，颜色分配：蓝色和红色。需要决定哪些字段用哪种颜色，可能需要交替使用或者根据重要性区分。比如，事件ID用红色，地点用蓝色，时间用红色，上报人用蓝色，这样交替使用会比较清晰。
#
# 然后，我需要构建HTML结构。先创建一个基本的HTML文档结构，包括head和body。在body中，使用段落标签<p>来展示每个字段，对关键字段应用内联样式，设置颜色。非关键字段如场景类型、网格码、经纬度、描述等，保持默认颜色。图片URL需要处理成可点击的链接，使用<a>标签，并设置target="_blank"在新标签页打开。
#
# 需要注意JSON中的字段名称可能需要转换为更易读的中文标签，比如"eventId"转换为“事件ID”，“reportLocation”转换为“上报位置”等。同时，时间格式可能需要调整，但用户提供的已经是正确的格式，所以直接使用即可。
#
# 接下来，检查是否有遗漏的字段，比如经纬度、描述，这些是否需要高亮。根据用户要求，可能不需要，所以保持黑色。然后，确保图片URL正确转换为链接，并且图片能正常显示。可能需要验证URL是否有效，但用户提供的链接可能是示例，所以不需要验证。
#
# 最后，生成完整的HTML代码，并检查格式是否正确，颜色应用是否恰当，没有语法错误。可能需要使用在线HTML验证工具检查，但作为基础转换，手动检查应该足够。确保所有关键字段都正确高亮，颜色交替合理，整体结构清晰易读。
# </think>
#
# 以下是转换为HTML富文本格式的内容，关键信息已用蓝色和红色标注：
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         .key-info-red { color: red; }
#         .key-info-blue { color: blue; }
#         .content { line-height: 1.6; }
#     </style>
# </head>
# <body>
#     <div class="content">
#         <p><strong>事件ID：</strong><span class="key-info-red">SX-2025-06-19-00001</span></p>
#         <p><strong>场景类型：</strong>泥头车</p>
#         <p><strong>上报位置：</strong><span class="key-info-blue">广东省深圳市福田区梅林街道林海山庄</span></p>
#         <p><strong>网格编码：</strong>440304008004003</p>
#         <p><strong>上报时间：</strong><span class="key-info-red">2025-06-20 06:48:20</span></p>
#         <p><strong>上报人：</strong><span class="key-info-blue">张三</span></p>
#         <p><strong>上报主体：</strong>城市管家</p>
#         <p><strong>图片证据：</strong><br>
#             <a href="https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/811702d688c348f8b0be009cb9b2805d.jpg" target="_blank">证据图片1</a><br>
#             <a href="https://city001-bt-test.obs.cn-south-1.myhuaweicloud.com/2025/07/07/7c7e65a9840b45688289c2b0be4da81a.jpg" target="_blank">证据图片2</a>
#         </p>
#         <p><strong>坐标：</strong>经度 121.473 / 纬度 31.230</p>
#         <p><strong>事件描述：</strong><br>
#         滨河路。东往西滨河新洲立交处，该车辆<strong class="key-info-red">超高超载</strong>，<strong class="key-info-red">未密闭</strong>，<strong class="key-info-red">沿途撒落</strong>。</p>
#     </div>
# </body>
# </html>
# ```
#
# 效果说明：
# 1. 使用红蓝双色标注核心要素（事件ID、地理位置、时间、人员信息等）
# 2. 违规行为描述中的关键问题使用红色强调
# 3. 图片链接可点击查看大图
# 4. 采用1.6倍行距提升可读性
# 5. 坐标信息保持标准格式
# 6. 所有关键字段名称加粗显示

# %%
#InternVL3-8B example
from openai import OpenAI

client = OpenAI(api_key="cg-ai_brain-InternVL3-8B-c56726f1022c122f2e095fc90bbb484VDS", base_url="http://223.2.249.70:7025/v1")

response = client.chat.completions.create(
    model="InternVL3-8B",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello"},
    ],
    stream=False
)

print(response.choices[0].message.content)
